# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoGalindoBulos/Evidencia-2/blob/main/Micro_Retailers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#Cargar archivo
from google.colab import files
files.upload()

# %%
#Cargarlo como xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Separo las columnas por cuantitativas y cualitativas
Cualitativa=Micro_Retailer.iloc[:,[7,9,10,11,12,15,18,19,20,23,24,25,26,27,28,30,32,34,35,36,37,38,39,40,46,47,48,50,52,53,54,55,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,79,80,82,83,84,85,86,87,88,89,91,92,93,94,95,96,97,98,99,100,101]]
Cualitativa.to_csv("Cualitativa.csv")
#from google.colab import files   
#files.download("Cualitativa.csv")

# %%
valores_nulos=Cualitativa.isnull().sum()
valores_nulos
# Out:
# 228_store_name                                             1
# 232_type_of_store                                          0
# 108_does_the_micro_retailer_has_a_barred_window_           0
# 99_does_the_micro_retailer_exhibits_products_outside_      0
# 102_does_the_micro_retailer_sells_fresh_products_          0
#                                                         ...
# 262_technology_serve_customers                           230
# 263_technology_secure_sales                              227
# 264_technology_budget                                    228
# 267_technology_investment_customer_preferences           228
# 234_willingness_participate_workshop                     166
# Length: 70, dtype: int64

# %%
#Limpiamos valores nulos para cada columna cualitativa
Cualitativa["228_store_name"] =Cualitativa["228_store_name"].fillna(method="ffill")
Cualitativa["232_type_of_store"] =Cualitativa["232_type_of_store"].fillna(method="ffill")
Cualitativa["108_does_the_micro_retailer_has_a_barred_window_"] =Cualitativa["108_does_the_micro_retailer_has_a_barred_window_"].fillna(method="ffill")
Cualitativa["99_does_the_micro_retailer_exhibits_products_outside_"] =Cualitativa["99_does_the_micro_retailer_exhibits_products_outside_"].fillna(method="ffill")
Cualitativa["102_does_the_micro_retailer_sells_fresh_products_"] =Cualitativa["102_does_the_micro_retailer_sells_fresh_products_"].fillna(method="ffill")
Cualitativa["184_store_devices"] =Cualitativa["184_store_devices"].fillna(method="ffill")
Cualitativa["hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz"] =Cualitativa["hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz"].fillna(method="ffill")
Cualitativa["le_comento_que_toda_esta_informacin_es_confidencial"] =Cualitativa["le_comento_que_toda_esta_informacin_es_confidencial"].fillna(method="ffill")
Cualitativa["233_date_establishment"] =Cualitativa["233_date_establishment"].fillna(method="bfill")
Cualitativa["5_change_store_space_last_year"] =Cualitativa["5_change_store_space_last_year"].fillna(method="ffill")
Cualitativa["6_change_employees_average_salary_last_year"] =Cualitativa["6_change_employees_average_salary_last_year"].fillna(method="bfill")
Cualitativa["20_reviews_finances_monthly"] =Cualitativa["20_reviews_finances_monthly"].fillna(method="ffill")
Cualitativa["49_inventory_records"] =Cualitativa["49_inventory_records"].fillna(method="bfill")
Cualitativa["18_sales_records"] =Cualitativa["18_sales_records"].fillna(method="bfill")
Cualitativa["155_sales_registers_used_for"] =Cualitativa["155_sales_registers_used_for"].fillna(method="bfill")
Cualitativa["19_tax_id"] =Cualitativa["19_tax_id"].fillna(method="ffill")
Cualitativa["310_burnout"] =Cualitativa["310_burnout"].fillna(method="bfill")
Cualitativa["186_internet_connection"] =Cualitativa["186_internet_connection"].fillna(method="bfill")
Cualitativa["210_sales_channels"] =Cualitativa["210_sales_channels"].fillna(method="bfill")
Cualitativa["189_payment_methods"] =Cualitativa["189_payment_methods"].fillna(method="ffill")
Cualitativa["28_prefered_payment_method"] =Cualitativa["28_prefered_payment_method"].fillna(method="bfill")
Cualitativa["31_different_prices_payment_method"] =Cualitativa["31_different_prices_payment_method"].fillna(method="bfill")
Cualitativa["269_cash_discount"] =Cualitativa["269_cash_discount"].fillna(method="bfill")
Cualitativa["270_card_extra_charge"] =Cualitativa["270_card_extra_charge"].fillna(method="bfill")
Cualitativa["30_payment_methods_large_purchases"] =Cualitativa["30_payment_methods_large_purchases"].fillna(method="bfill")
Cualitativa["214_customer_relationship_tools"] =Cualitativa["214_customer_relationship_tools"].fillna(method="bfill")
Cualitativa["33_credit_to_customers"] =Cualitativa["33_credit_to_customers"].fillna(method="ffill")
Cualitativa["35_interest_rate"] =Cualitativa["35_interest_rate"].fillna(method="bfill")
Cualitativa["38_average_margin_profits"] =Cualitativa["38_average_margin_profits"].fillna(method="bfill")
Cualitativa["193_sales_planning_tools"] =Cualitativa["193_sales_planning_tools"].fillna(method="ffill")
Cualitativa["227_agreement_ecommerce_platforms"] =Cualitativa["227_agreement_ecommerce_platforms"].fillna(method="ffill")
Cualitativa["60_services"] =Cualitativa["60_services"].fillna(method="bfill")
Cualitativa["77_delivery_timeslots"] =Cualitativa["77_delivery_timeslots"].fillna(method="bfill")
Cualitativa["79_delivery_vehicle"] =Cualitativa["79_delivery_vehicle"].fillna(method="bfill")
Cualitativa["64_comission_services"] =Cualitativa["64_comission_services"].fillna(method="bfill")
Cualitativa["66_percentaje_services_income"] =Cualitativa["66_percentaje_services_income"].fillna(method="bfill")
Cualitativa["69_why_not_services"] =Cualitativa["69_why_not_services"].fillna(method="bfill")
Cualitativa["311_topups"] =Cualitativa["311_topups"].fillna(method="bfill")
Cualitativa["312_payment_of_utilities"] =Cualitativa["312_payment_of_utilities"].fillna(method="bfill")
Cualitativa["313_home_deliveries"] =Cualitativa["313_home_deliveries"].fillna(method="bfill")
Cualitativa["314_reception_delivery_packages"] =Cualitativa["314_reception_delivery_packages"].fillna(method="bfill")
Cualitativa["42_willingness_share_inventory_data_suppliers"] =Cualitativa["42_willingness_share_inventory_data_suppliers"].fillna(method="bfill")
Cualitativa["44_willingness_inventory_management_suppliers"] =Cualitativa["44_willingness_inventory_management_suppliers"].fillna(method="bfill")
Cualitativa["45_willingness_reorder_suppliers"] =Cualitativa["45_willingness_reorder_suppliers"].fillna(method="bfill")
Cualitativa["46_willingness_reorder_suppliers_variety"] =Cualitativa["46_willingness_reorder_suppliers_variety"].fillna(method="bfill")
Cualitativa["47_willingness_reorder_suppliers_lower_prices"] =Cualitativa["47_willingness_reorder_suppliers_lower_prices"].fillna(method="bfill")
Cualitativa["43_willingness_share_sales_data_suppliers"] =Cualitativa["43_willingness_share_sales_data_suppliers"].fillna(method="bfill")
Cualitativa["58_willingness_share_sales_data_mse"] =Cualitativa["58_willingness_share_sales_data_mse"].fillna(method="bfill")
Cualitativa["59_willingness_share_sales_data_mse_better_prices"] =Cualitativa["59_willingness_share_sales_data_mse_better_prices"].fillna(method="bfill")
Cualitativa["185_place_orders_suppliers"] =Cualitativa["185_place_orders_suppliers"].fillna(method="bfill")
Cualitativa["53_special_conditions_suppliers"] =Cualitativa["53_special_conditions_suppliers"].fillna(method="bfill")


Cualitativa["192_procurement_planning_tools"] =Cualitativa["192_procurement_planning_tools"].fillna(method="bfill")
Cualitativa["277_payment_method_suppliers"] =Cualitativa["277_payment_method_suppliers"].fillna(method="bfill")

Cualitativa["56_procurement_changes_pandemic"] =Cualitativa["56_procurement_changes_pandemic"].fillna(method="ffill")
Cualitativa["279_changes_procurement_pandemic"] =Cualitativa["279_changes_procurement_pandemic"].fillna(method="bfill")
Cualitativa["157_frequency_organize_shelves"] =Cualitativa["157_frequency_organize_shelves"].fillna(method="ffill")
Cualitativa["158_charact_organize_products_on_shelves"] =Cualitativa["158_charact_organize_products_on_shelves"].fillna(method="ffill")
Cualitativa["161_actions_stockouts"] =Cualitativa["161_actions_stockouts"].fillna(method="ffill")
Cualitativa["162_inventory_extra_space"] =Cualitativa["162_inventory_extra_space"].fillna(method="ffill")
Cualitativa["249_technology_training"] =Cualitativa["249_technology_training"].fillna(method="bfill")
Cualitativa["250_technology_investment_operations"] =Cualitativa["250_technology_investment_operations"].fillna(method="bfill")
Cualitativa["251_technology_investment_customers"] =Cualitativa["251_technology_investment_customers"].fillna(method="ffill")
Cualitativa["254_technology_roadmap"] =Cualitativa["254_technology_roadmap"].fillna(method="ffill")
Cualitativa["260_technology_scalable"] =Cualitativa["260_technology_scalable"].fillna(method="ffill")
Cualitativa["261_technology_organization"] =Cualitativa["261_technology_organization"].fillna(method="bfill")
Cualitativa["262_technology_serve_customers"] =Cualitativa["262_technology_serve_customers"].fillna(method="ffill")
Cualitativa["263_technology_secure_sales"] =Cualitativa["263_technology_secure_sales"].fillna(method="ffill")
Cualitativa["264_technology_budget"] =Cualitativa["264_technology_budget"].fillna(method="ffill")
Cualitativa["267_technology_investment_customer_preferences"] =Cualitativa["267_technology_investment_customer_preferences"].fillna(method="ffill")
Cualitativa["234_willingness_participate_workshop"] =Cualitativa["234_willingness_participate_workshop"].fillna(method="ffill")


valores_nulos=Cualitativa.isnull().sum()
valores_nulos
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Cualitativa.to_csv("Cualitativa.csv")
from google.colab import files   
files.download("Cualitativa.csv")

# %%
#Separamos las variables cuantitativas
Cuantitativa=Micro_Retailer.iloc[:,[13,14,16,21,22,29,31,33,42,49,51,56,57,58,59,60,78]]
Cuantitativa

# %%
valores_nulos=Cuantitativa.isnull().sum()
valores_nulos
# Out:
# 97_number_of_customers_in_store                        0
# 268_number_fridges                                    20
# 104_how_many_shelves_does_the_micro_retailer_have      0
# 2_current_permanent_employees                        156
# 4_number_permanent_employees_last_year               176
# 103_number_own_fridges                               340
# 145_number_direct_competitors                        166
# 24_burnout                                           338
# 272_card_days_receive_money                          327
# 276_expected_days_informal_credit                    396
# 36_credit_default_rate                               410
# 315_frequency_topups                                 407
# 316_frequency_utility_bills                          432
# 317_home_deliveries                                  394
# 62_frequency_only_services                           361
# 78_number_home_deliveries_week                       439
# ...

# %%
#Limpiamos valores nulos de las variables cuantitativas
Cuantitativa["97_number_of_customers_in_store"]=Cuantitativa["97_number_of_customers_in_store"].fillna(round(Cuantitativa["97_number_of_customers_in_store"].mean(),1))
Cuantitativa["268_number_fridges"]=Cuantitativa["268_number_fridges"].fillna(round(Cuantitativa["268_number_fridges"].mean(),1))
Cuantitativa["104_how_many_shelves_does_the_micro_retailer_have"]=Cuantitativa["104_how_many_shelves_does_the_micro_retailer_have"].fillna(round(Cuantitativa["104_how_many_shelves_does_the_micro_retailer_have"].mean(),1))
Cuantitativa["2_current_permanent_employees"]=Cuantitativa["2_current_permanent_employees"].fillna(round(Cuantitativa["2_current_permanent_employees"].mean(),1))
Cuantitativa["4_number_permanent_employees_last_year"]=Cuantitativa["4_number_permanent_employees_last_year"].fillna(round(Cuantitativa["4_number_permanent_employees_last_year"].mean(),1))
Cuantitativa["103_number_own_fridges"]=Cuantitativa["103_number_own_fridges"].fillna(round(Cuantitativa["103_number_own_fridges"].mean(),1))
Cuantitativa["145_number_direct_competitors"]=Cuantitativa["145_number_direct_competitors"].fillna(round(Cuantitativa["145_number_direct_competitors"].mean(),1))
Cuantitativa["24_burnout"]=Cuantitativa["24_burnout"].fillna(round(Cuantitativa["24_burnout"].mean(),1))
Cuantitativa["272_card_days_receive_money"]=Cuantitativa["272_card_days_receive_money"].fillna(round(Cuantitativa["272_card_days_receive_money"].mean(),1))
Cuantitativa["276_expected_days_informal_credit"]=Cuantitativa["276_expected_days_informal_credit"].fillna(round(Cuantitativa["276_expected_days_informal_credit"].mean(),1))
Cuantitativa["36_credit_default_rate"]=Cuantitativa["36_credit_default_rate"].fillna(round(Cuantitativa["36_credit_default_rate"].mean(),1))
Cuantitativa["315_frequency_topups"]=Cuantitativa["315_frequency_topups"].fillna(round(Cuantitativa["315_frequency_topups"].mean(),1))
Cuantitativa["316_frequency_utility_bills"]=Cuantitativa["316_frequency_utility_bills"].fillna(round(Cuantitativa["316_frequency_utility_bills"].mean(),1))
Cuantitativa["317_home_deliveries"]=Cuantitativa["317_home_deliveries"].fillna(round(Cuantitativa["317_home_deliveries"].mean(),1))
Cuantitativa["62_frequency_only_services"]=Cuantitativa["62_frequency_only_services"].fillna(round(Cuantitativa["62_frequency_only_services"].mean(),1))
Cuantitativa["78_number_home_deliveries_week"]=Cuantitativa["78_number_home_deliveries_week"].fillna(round(Cuantitativa["78_number_home_deliveries_week"].mean(),1))
Cuantitativa["172_supplier_frequency"]=Cuantitativa["172_supplier_frequency"].fillna(round(Cuantitativa["172_supplier_frequency"].mean(),1))

valores_nulos=Cuantitativa.isnull().sum()
valores_nulos

# %%
y=Cuantitativa
  
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
#Encontramos Ouliers del Dataframe
outliers= Cuantitativa[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers

# %%
Cuantitativa= Cuantitativa[(y<=Limite_Superior)&(y>=Limite_Inferior)]
Cuantitativa

# %%
valores_nulos=Cuantitativa.isnull().sum()
valores_nulos
# Out:
# 97_number_of_customers_in_store                      10
# 268_number_fridges                                    7
# 104_how_many_shelves_does_the_micro_retailer_have    13
# 2_current_permanent_employees                         5
# 4_number_permanent_employees_last_year                4
# 103_number_own_fridges                                5
# 145_number_direct_competitors                        12
# 24_burnout                                           32
# 272_card_days_receive_money                           9
# 276_expected_days_informal_credit                     8
# 36_credit_default_rate                                6
# 315_frequency_topups                                  5
# 316_frequency_utility_bills                           1
# 317_home_deliveries                                   2
# 62_frequency_only_services                            6
# 78_number_home_deliveries_week                        5
# 172_supplier_frequency                               27
# ...

# %%
Cuantitativa=Cuantitativa.fillna(round(Cuantitativa.mean(),1))
Cuantitativa

# %%
valores_nulos=Cuantitativa.isnull().sum()
valores_nulos
# Out:
# 97_number_of_customers_in_store                      0
# 268_number_fridges                                   0
# 104_how_many_shelves_does_the_micro_retailer_have    0
# 2_current_permanent_employees                        0
# 4_number_permanent_employees_last_year               0
# 103_number_own_fridges                               0
# 145_number_direct_competitors                        0
# 24_burnout                                           0
# 272_card_days_receive_money                          0
# 276_expected_days_informal_credit                    0
# 36_credit_default_rate                               0
# 315_frequency_topups                                 0
# 316_frequency_utility_bills                          0
# 317_home_deliveries                                  0
# 62_frequency_only_services                           0
# 78_number_home_deliveries_week                       0
# 172_supplier_frequency                               0
# dtype: int64

# %%
Datos_limpios = pd.concat([Cualitativa, Cuantitativa], axis=1)
Datos_limpios
# Out:
#                                         228_store_name  \
# 0                                   MINI SUPER 3 NORTE
# 1                                          Miscelánea
# 2                                Miscelánea casa cruz
# 3                                   SUPER & ALMACENES
# 4                                           Ranita “V”
# ..                                                 ...
# 439                                      Xuti Galería
# 440                                         July Store
# 441                                          La fonda
# 442  Birria de Res "Hermanos Negreros 2" estilo Tij...
# 443                          Restaurante el alfeñique
#
#                    232_type_of_store  \
# 0     Grocery store (aka. nanostore)
# 1     Grocery store (aka. nanostore)
# 2     Grocery store (aka. nanostore)
# 3                          Chacharas
# 4     Grocery store (aka. nanostore)
# ..                               ...
# 439         productos tradicionales
# ...

# %%
Datos_limpios.to_csv("Datos_limpios.csv")

# %%
from google.colab import files   
files.download("Datos_limpios.csv")
